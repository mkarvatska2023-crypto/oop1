# %%
import random
mmds = ["червоний", "жовтий", "зелений", "блакитний", "синій", "фіолетовий"]
pack_base = mmds * 20
pack  = random.shuffle (pack_base)
pack = pack_base[:100]
i = 0
while pack:
    m_color = pack.pop()
    i += 1
    print (f"{i}: {m_color}")
    if m_color == "червоний":
        print ("Правильно!")
    else:
        print (f"Неправильно! Правильна відповідь: {m_color}")
m_color = random.choice (mmds)
# Out:
# 1: зелений
# Неправильно! Правильна відповідь: зелений
# 2: жовтий
# Неправильно! Правильна відповідь: жовтий
# 3: блакитний
# Неправильно! Правильна відповідь: блакитний
# 4: зелений
# Неправильно! Правильна відповідь: зелений
# 5: червоний
# Правильно!
# 6: червоний
# Правильно!
# 7: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 8: жовтий
# Неправильно! Правильна відповідь: жовтий
# 9: блакитний
# Неправильно! Правильна відповідь: блакитний
# 10: блакитний
# Неправильно! Правильна відповідь: блакитний
# 11: червоний
# Правильно!
# 12: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 13: зелений
# Неправильно! Правильна відповідь: зелений
# 14: червоний
# Правильно!
# 15: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 16: червоний
# Правильно!
# 17: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 18: жовтий
# Неправильно! Правильна відповідь: жовтий
# 19: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 20: червоний
# Правильно!
# 21: зелений
# Неправильно! Правильна відповідь: зелений
# 22: червоний
# Правильно!
# 23: синій
# Неправильно! Правильна відповідь: синій
# 24: жовтий
# Неправильно! Правильна відповідь: жовтий
# 25: блакитний
# Неправильно! Правильна відповідь: блакитний
# 26: синій
# Неправильно! Правильна відповідь: синій
# 27: червоний
# Правильно!
# 28: жовтий
# Неправильно! Правильна відповідь: жовтий
# 29: зелений
# Неправильно! Правильна відповідь: зелений
# 30: червоний
# Правильно!
# 31: блакитний
# Неправильно! Правильна відповідь: блакитний
# 32: червоний
# Правильно!
# 33: блакитний
# Неправильно! Правильна відповідь: блакитний
# 34: синій
# Неправильно! Правильна відповідь: синій
# 35: червоний
# Правильно!
# 36: синій
# Неправильно! Правильна відповідь: синій
# 37: жовтий
# Неправильно! Правильна відповідь: жовтий
# 38: червоний
# Правильно!
# 39: жовтий
# Неправильно! Правильна відповідь: жовтий
# 40: жовтий
# Неправильно! Правильна відповідь: жовтий
# 41: жовтий
# Неправильно! Правильна відповідь: жовтий
# 42: блакитний
# Неправильно! Правильна відповідь: блакитний
# 43: зелений
# Неправильно! Правильна відповідь: зелений
# 44: червоний
# Правильно!
# 45: червоний
# Правильно!
# 46: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 47: жовтий
# Неправильно! Правильна відповідь: жовтий
# 48: червоний
# Правильно!
# 49: зелений
# Неправильно! Правильна відповідь: зелений
# 50: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 51: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 52: червоний
# Правильно!
# 53: зелений
# Неправильно! Правильна відповідь: зелений
# 54: зелений
# Неправильно! Правильна відповідь: зелений
# 55: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 56: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 57: блакитний
# Неправильно! Правильна відповідь: блакитний
# 58: синій
# Неправильно! Правильна відповідь: синій
# 59: жовтий
# Неправильно! Правильна відповідь: жовтий
# 60: блакитний
# Неправильно! Правильна відповідь: блакитний
# 61: зелений
# Неправильно! Правильна відповідь: зелений
# 62: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 63: блакитний
# Неправильно! Правильна відповідь: блакитний
# 64: блакитний
# Неправильно! Правильна відповідь: блакитний
# 65: червоний
# Правильно!
# 66: жовтий
# Неправильно! Правильна відповідь: жовтий
# 67: зелений
# Неправильно! Правильна відповідь: зелений
# 68: червоний
# Правильно!
# 69: блакитний
# Неправильно! Правильна відповідь: блакитний
# 70: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 71: зелений
# Неправильно! Правильна відповідь: зелений
# 72: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 73: жовтий
# Неправильно! Правильна відповідь: жовтий
# 74: блакитний
# Неправильно! Правильна відповідь: блакитний
# 75: червоний
# Правильно!
# 76: синій
# Неправильно! Правильна відповідь: синій
# 77: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 78: зелений
# Неправильно! Правильна відповідь: зелений
# 79: синій
# Неправильно! Правильна відповідь: синій
# 80: синій
# Неправильно! Правильна відповідь: синій
# 81: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 82: блакитний
# Неправильно! Правильна відповідь: блакитний
# 83: зелений
# Неправильно! Правильна відповідь: зелений
# 84: фіолетовий
# Неправильно! Правильна відповідь: фіолетовий
# 85: жовтий
# Неправильно! Правильна відповідь: жовтий
# 86: жовтий
# Неправильно! Правильна відповідь: жовтий
# 87: зелений
# Неправильно! Правильна відповідь: зелений
# 88: зелений
# Неправильно! Правильна відповідь: зелений
# 89: синій
# Неправильно! Правильна відповідь: синій
# 90: жовтий
# Неправильно! Правильна відповідь: жовтий
# 91: синій
# Неправильно! Правильна відповідь: синій
# 92: синій
# Неправильно! Правильна відповідь: синій
# 93: жовтий
# Неправильно! Правильна відповідь: жовтий
# 94: зелений
# Неправильно! Правильна відповідь: зелений
# 95: блакитний
# Неправильно! Правильна відповідь: блакитний
# 96: синій
# Неправильно! Правильна відповідь: синій
# 97: блакитний
# Неправильно! Правильна відповідь: блакитний
# 98: синій
# Неправильно! Правильна відповідь: синій
# 99: синій
# Неправильно! Правильна відповідь: синій
# 100: жовтий
# Неправильно! Правильна відповідь: жовтий

# %% [markdown]
# Завдання
# - кидаємо кубик поки не випаде 6

# %%
import random

dice = None  # початкове значення

while dice != 6:  # цикл триватиме, поки не випаде 6
    dice = random.randint(1, 6)
    print(f"Мені випало {dice}")

print(" Нарешті випала шістка!")
# Out:
# Мені випало 5
# Мені випало 6
#  Нарешті випала шістка!

# %%
import random
for i in range (100):
    dice = random.randint (1, 6)
    print (f"{i} Мені випало {dice}")
    if dice == 6:
        print ("Випала шістка, завершуємо")
        break
# Out:
# 0 Мені випало 4
# 1 Мені випало 2
# 2 Мені випало 5
# 3 Мені випало 6
# Випала шістка, завершуємо
